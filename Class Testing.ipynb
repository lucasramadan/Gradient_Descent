# %%
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
from BaseGradDesc import BaseGradDesc

# %%
bgd = BaseGradDesc()

# %%
X, Y = bgd.generate_data()

# %%
bgd.fit(X, Y)

# %%
bgd.plot_data()

# %%
bgd.weights
# Out:
# array([-4.26355101,  4.20173673])

# %%
bgd.plot_weights()

# %%
bgd.plot_performance()

# %%
bgd.plot_steps()

# %% [markdown]
# ### Now LineSearch

# %% [markdown]
# ### Now Momentum

# %%
from MomentumGradDesc import MomGradDesc

# %%
mgd = MomGradDesc()

# %%
mgd.fit(X, Y)

# %%
mgd.weights
# Out:
# array([-4.27938477,  4.21761015])

# %%
mgd.plot_performance()

# %%
mgd.plot_weights()

# %%
mgd.plot_steps()

# %% [markdown]
# ### Now Nesterov's

# %%
from NesterovsAcceleratedGradDesc import NAGD

# %%
nagd = NAGD(n_steps=1000)

# %%
nagd.fit(X, Y)

# %%
nagd.weights
# Out:
# array([-4.2306619 ,  4.16877792])

# %%
nagd.plot_performance()

# %%
nagd.plot_weights()

# %%
nagd.plot_steps()

# %% [markdown]
# ### Now AdaGrad

# %%
from AdaGrad import AdaGrad

# %%
adg = AdaGrad()

# %%
adg.fit(X, Y)

# %%
adg.weights
# Out:
# array([-4.21009235,  4.17881498])

# %%
adg.plot_performance()

# %%
adg.plot_steps()

# %%
adg.plot_weights()

# %% [markdown]
# ### Now AdaDelta

# %%
from AdaDelta import AdaDelta

# %%
addg = AdaDelta(n_steps=1000)

# %%
addg.fit(X, Y)

# %%
addg.weights
# Out:
# array([-4.21169862,  4.14977523])

# %%
addg.plot_weights()

# %%
addg.plot_performance()

# %%
addg.plot_steps()

# %% [markdown]
# ### Finally, Adam

# %%
from Adam import AdamGD

# %%
adam = AdamGD()

# %%
adam.fit(X, Y)

# %%
adam.weights
# Out:
# array([-4.25122826,  4.18938351])

# %%
adam.plot_weights()

# %%
adam.plot_performance()

# %%
adam.plot_steps()

# %% [markdown]
# ### Next will be Conjugate Gradient

# %%
from ConjugateGradDesc import ConjugateGD

# %%
cgd = ConjugateGD()

# %%
X, Y = cgd.generate_data()

# %%
cgd.plot_data()

# %%
cgd.fit(X, Y)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.052978
#          Iterations: 110
#          Function evaluations: 1281
#          Gradient evaluations: 1281

# %%
cgd.weights
# Out:
# array([-8.15574101,  8.02614651])

# %% [markdown]
# ### Now BFGS

# %%
from BFGSGradDesc import BFGSGD

# %%
bfgsgd = BFGSGD()

# %%
X, Y = bfgsgd.generate_data()

# %%
bfgsgd.fit(X, Y)

# %%
 bfgsgd.weights
# Out:
# array([-8.12019815,  8.05743807])
